# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Data

# %%
## load the data into a pandas DataFrame object
data = pd.read_csv('/Users/csstnns/Desktop/Python Data Course - Oct2020/Day 1/trades_missing_values.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   traderID   29 non-null     int64
#  1   ValueBuy   27 non-null     object
#  2   ValueSell  28 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 824.0+ bytes

# %%
## numeric columns
data.describe()
# Out:
#         traderID
# count  29.000000
# mean    2.448276
# std     1.120784
# min     1.000000
# 25%     1.000000
# 50%     3.000000
# 75%     3.000000
# max     4.000000

# %%
data.isnull().any()
# Out:
# traderID     False
# ValueBuy      True
# ValueSell     True
# dtype: bool

# %%
#data.dropna(inplace=True)

# %%
## replace ? with a np.nan
data.replace('?',np.nan,inplace=True)

# %%
median_values = data.median()
values = {'traderID': 1, 'ValueBuy': median_values[1], 'ValueSell': median_values[2]}
data = data.fillna(value=values)

# %%
for column in data.columns:
    ## if this column is not numeric then apply this 
    data[column] = data[column].astype(int)
# Out:
# /Users/csstnns/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['ValueBuy'])
# Out:
# pandas.core.series.Series

# %%
data = data[['ValueSell','ValueBuy']]

# %%
data
# Out:
#    ValueSell ValueBuy
# 0        116       61
# 1        129      118
# 2         90       78
# 3         93      136
# 4         93       52
# 5         81       96
# 6        100      123
# 7         59       84
# 8         21       37
# 9         25       35
# 10        28       40
# 11        26       37
# 12        38       39
# 13        40       37
# 14       216       78
# 15       213       78
# 16       204      213
# 17       217      211
# 18        93      201
# 19       211      218
# 20       202       78
# 21       211      209
# 22       220      213
# 23        98       78
# 24        87       42
# 25        45       62
# 26        88       51
# 27        95       74
# 28        51       82

# %%
data[ (data['ValueSell'] > 200) & (data['ValueBuy'] > 210) ]
# Out:
#     ValueSell  ValueBuy
# 16        204       213
# 17        217       211
# 19        211       218
# 22        220       213

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ValueSell  29 non-null     int64
#  1   ValueBuy   29 non-null     int64
# dtypes: int64(2)
# memory usage: 592.0 bytes

# %%
# load the data into a pandas DataFrame object
cars = pd.read_csv('/Users/csstnns/Desktop/Python Data Course - Oct2020/Day 2/mtcars.csv')

# %%
cars.shape
# Out:
# (32, 12)

# %%
cars.rename(columns={'Unnamed: 0':'make_model'}, inplace=True)
cars.columns
# Out:
# Index(['make_model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
cars.head()
# Out:
#           make_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
make_list = ['Toyota Corolla','Mazda RX4']
cars[
    (cars['gear'] >= 4) & 
     (cars['make_model'].isin(make_list)) 
]
# Out:
#   make_model   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb
# 0  Mazda RX4  21.0    6  160.0  110   3.9  2.62  16.46   0   1     4     4

# %%
cars.filter()

# %%
dir(cars)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
df = pd.DataFrame(
    {
        "A": [1, 2, 3], 
        "B": [4, 5, 6]
    }
)

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.rename(columns={"A": "a"}, inplace=True)

# %%
df
# Out:
#    a  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
cars_matrix = cars.values

# %%
type(cars_matrix)
# Out:
# numpy.ndarray

# %%
#cars
cars_matrix[0,-1] = 5

# %%
cars_matrix[0,:]
# Out:
# array(['Mazda RX4', 21.0, 6, 160.0, 110, 3.9, 2.62, 16.46, 0, 1, 4, 5],
#       dtype=object)

# %%
cars
# Out:
#              make_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
goose_data = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/goose/goose_rawdata.csv')

# %%
goose_data.query('(goose_eggs < 8 | broken_eggs > 3) & team == "SLN"')
# Out:
#                     name  year team league  goose_eggs  broken_eggs  mehs  \
# 1           Mike Kircher  1921  SLN     NL           0            1     0
# 3              Lou North  1921  SLN     NL          10            4     0
# 12          Tink Riviere  1921  SLN     NL           0            1     0
# 23         Ferdie Schupp  1921  SLN     NL           1            0     0
# 25            Roy Walker  1921  SLN     NL           1            0     0
# ...                  ...   ...  ...    ...         ...          ...   ...
# 30457  Samuel Tuivailala  2016  SLN     NL           0            0     0
# 30476       Jaime Garcia  2016  SLN     NL           0            0     0
# 30490        Matt Bowman  2016  SLN     NL          11            5     3
# 30500    Jerome Williams  2016  SLN     NL           0            0     0
# 30517          Zach Duke  2016  SLN     NL           2            2     1
#
#        league_average_gpct  ppf  replacement_gpct      gwar key_retro
# ...

# %%
goose_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30962 entries, 0 to 30961
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 30962 non-null  object
#  1   year                 30962 non-null  int64
#  2   team                 30962 non-null  object
#  3   league               30962 non-null  object
#  4   goose_eggs           30962 non-null  int64
#  5   broken_eggs          30962 non-null  int64
#  6   mehs                 30962 non-null  int64
#  7   league_average_gpct  30962 non-null  float64
#  8   ppf                  30962 non-null  int64
#  9   replacement_gpct     30962 non-null  float64
#  10  gwar                 20929 non-null  float64
#  11  key_retro            30962 non-null  object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 2.8+ MB
